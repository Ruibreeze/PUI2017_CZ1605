# %%
from __future__ import print_function
import sys
import os
import json
import urllib
import pandas as pd
import numpy as np
# %pylab inline
plt.rc('font', size=15)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("/gws/open/NYCOpenData/nycopendata/data/6bic-qvek/1414246044/6bic-qvek")

# %%
data.head(10)
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
# 5              10006                   6             2            0.33
# 6              10007                   1             0            0.00
# 7              10009                   2             0            0.00
# 8              10010                   0             0            0.00
# 9              10011                   3             2            0.67
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# ...

# %%
data.drop(data.columns[2:],axis=1,inplace=True)

# %%
data.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS
# 0              10001                  44
# 1              10002                  35
# 2              10003                   1
# 3              10004                   0
# 4              10005                   2

# %%
plt.scatter(data["JURISDICTION NAME"],data["COUNT PARTICIPANTS"])
plt.xlabel('JURISDICTION NAME')
plt.ylabel('COUNT PARTICIPANTS')
plt.title('Reducted Dataframe')
plt.legend(loc="upper right")
plt.show()
