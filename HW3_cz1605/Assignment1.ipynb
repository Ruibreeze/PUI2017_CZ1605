# %%
from __future__ import print_function
import pylab as pl
import seaborn
from scipy.optimize import curve_fit, minimize
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Distribution of Chisquare

# %%
distributions = ['chisq']

# %%
mymean = 100

# %%
df = mymean

# %%
import numpy as np
md = {}
md['chisq'] = np.random.chisquare(df, size=100)
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure1: distribution of Chi squared, df=100, size=100

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 101.39, standard deviation: 12.60

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['chisq'] = {} 

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure2: In general, the larger the sample size, the closer the sample mean gets to df value(100)

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Distribution of poisson

# %%
distributions = ['pois']

# %%
lam = mymean

# %%
md = {}
md['pois'] = np.random.poisson(lam, size=100)
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure1: distribution of poisson, lam=100, size=100

# %%
print ("Pois mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Pois mean: 99.72, standard deviation: 10.02

# %%
md['pois'] = {} 

for n in mysize:
    md['pois'][n] = np.random.poisson(lam, size = n)

md['pois']['means'] = {}
axpois_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axpois_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('Poisson', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [lam, lam], 'k')

# %% [markdown]
# ### Figure2: In general, the larger the sample size, the closer the sample mean gets to lam value(100)

# %%
allmeans1 = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans1,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Distribution of normal

# %%
distributions = ['normal']

# %%
loc = mymean

# %%
md = {}
md['normal'] = np.random.normal(loc, scale=1.0,size=100)
pl.hist(md['normal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure1: distribution of normal, loc=100, scale=1.0 size=100

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['normal'].mean(), md['normal'].std()))
# Out:
# Normal mean: 99.96, standard deviation: 0.96

# %%
md['normal'] = {} 

for n in mysize:
    md['normal'][n] = np.random.normal(loc, scale=1.0,size=100)

md['normal']['means'] = {}
axnormal_mu_n = pl.figure(figsize=(12,6)).add_subplot(111)

for nn in md['normal']:
    if not type(nn) == str:
        md['normal']['means'][nn] = md['normal'][nn].mean()
        axnormal_mu_n.plot(nn, md['normal']['means'][nn], 'o')
        axnormal_mu_n.set_xlabel('sample size', fontsize=18)
        axnormal_mu_n.set_ylabel('sample mean', fontsize=18)
        axnormal_mu_n.set_title('Normal', fontsize=18)
        axnormal_mu_n.plot([min(mysize), max(mysize)], [100, 100], 'k')

# %% [markdown]
# ### Figure2: In general, the larger the sample size, the closer the sample mean gets to loc value(100)

# %%
allmeans2 = list(md['normal']['means'].values())

pl.figure(figsize=(12, 8))
pl.hist(allmeans2,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Distribution of binomial

# %%
distributions = ['binomial']

# %%
md = {}
md['binomial'] = np.random.binomial(1000, 0.1, size=100)
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure1: distribution of binomial, n=1000, p=0.1 size=100

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 100.67, standard deviation: 10.30

# %%
md['binomial'] = {} 

for n in mysize:
    md['binomial'][n] = np.random.binomial(1000, 0.1, size=100)

md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('Binomial', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [100, 100], 'k')

# %% [markdown]
# ### Figure2: In general, the larger the sample size, the closer the sample mean gets to n*p value(100).

# %%
allmeans3 = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans3,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# # Distribution of geometric

# %%
distributions = ['geometric']

# %%
p = 1/float(mymean)

# %%
md = {}
md['geometric'] = np.random.geometric(p, size=100)
pl.hist(md['geometric'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure1: distribution of geometric, p=0.01 size=100

# %%
print ("geometric mean: %.2f, standard deviation: %.2f"%(md['geometric'].mean(), md['geometric'].std()))
# Out:
# geometric mean: 110.17, standard deviation: 105.81

# %%
md['geometric'] = {} 

for n in mysize:
    md['geometric'][n] = np.random.geometric(p, size = n)

md['geometric']['means'] = {}
axgeometric_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['geometric']:
    if not type(nn) == str:
        md['geometric']['means'][nn] = md['geometric'][nn].mean()
        axgeometric_mu_n.plot(nn, md['geometric']['means'][nn], 'o')
        axgeometric_mu_n.set_xlabel('sample size', fontsize=18)
        axgeometric_mu_n.set_ylabel('sample mean', fontsize=18)
        axgeometric_mu_n.set_title('Geometric', fontsize=18)
        axgeometric_mu_n.plot([min(mysize), max(mysize)], [100, 100], 'k')

# %% [markdown]
# ### Figure2: In general, the larger the sample size, the closer the sample mean gets to mymean(100).

# %%
allmeans4 = list(md['geometric']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans4,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
